# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle

# %% [markdown]
# # Resumo da Amostragem BBC

# %%
answers=[]
for f in os.listdir("../../Objetos/Objetos Processados Amostra/Binario/"):
    answers=answers+pickle.load(open("../../Objetos/Objetos Processados Amostra/Binario/"+f,"rb"))

# %%
for f in os.listdir("../../Objetos/Objetos Processados Amostra/TF/"):
    if "8" not in f:
        answers=answers+pickle.load(open("../../Objetos/Objetos Processados Amostra/TF/"+f,"rb"))

# %%
os.listdir("../../Objetos/Objetos Processados Amostra/TFIDF/")
# Out:
# ['TFIDF2.jojo',
#  'TFIDF3.jojo',
#  'TFIDF4.jojo',
#  'TFIDF5.jojo',
#  'TFIDF6.jojo',
#  'TFIDF7.jojo']

# %%
for f in os.listdir("../../Objetos/Objetos Processados Amostra/TFIDF/"):
    if "8" not in f:
        answers=answers+pickle.load(open("../../Objetos/Objetos Processados Amostra/TFIDF/"+f,"rb"))

# %%
len(answers)
# Out:
# 432

# %%
resp= answers

# %%
resp= sorted(resp,key= lambda x: x[0])

# %%
resp[-10:-1]
# Out:
# [(0.16167236082935968,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16184101061327236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16333085713546908,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.16391603784766551,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16553209534864324,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16713600927673644,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17348930388890527,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17592454967187623,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.17930798376732812,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'})]

# %% [markdown]
# # Resumo da amostragem Reuters

# %%
answers=[]
for f in os.listdir("../../Objetos/ObjetosProcessadosReutersAmostra/Binario/"):
    answers=answers+pickle.load(open("../../Objetos/ObjetosProcessadosReutersAmostra/Binario/"+f,"rb"))

# %%
for f in os.listdir("../../Objetos/ObjetosProcessadosReutersAmostra/TF/"):
    answers=answers+pickle.load(open("../../Objetos/ObjetosProcessadosReutersAmostra/TF/"+f,"rb"))

# %%
for f in os.listdir("../../Objetos/ObjetosProcessadosReutersAmostra/TFIDF/"):
    answers=answers+pickle.load(open("../../Objetos/ObjetosProcessadosReutersAmostra/TFIDF/"+f,"rb"))

# %%
resp= sorted(answers,key= lambda x: x[0])

# %%
resp[-10:-1]
# Out:
# [(0.23613047762693348,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.23892775766801266,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.24340833896944339,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.24390213400223007,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.2447065012587977,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.25308890442280352,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.25510583365792655,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.26568783893198888,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.30480955410696609,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'reuters',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'})]

# %% [markdown]
# # Resumo SOM BBC

# %%
resp=[]
for f in os.listdir("../../Objetos/Objetos Processados Amostra SOM/BBC"):
    resp=resp+pickle.load(open("../../Objetos/Objetos Processados Amostra SOM/BBC/"+f,"rb"))

# %%
resp
# Out:
# [(0.0058145540443177166,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.013974110733340275,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.021898657650540356,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018388304740773076,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0024900817972008664,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0023923987758321286,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0069865917950994996,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0032699672808389015,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.012756206102926441,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.00011655082895018904,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.011290909560489339,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.016569437846368888,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.01364326112424202,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0076146081272948016,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.019304598563022152,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.016021842355357967,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.021045176869891196,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.037125405764016531,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0085955162593485991,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018015083013968109,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0012160170329742429,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0059340412293830257,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015050302914576355,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.024859843981589098,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0067319309216664312,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-3.647939776266438e-05,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025528811588906471,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01833896233846425,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022653322621346107,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.024552477134206017,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0073021435045768322,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0092148611813814719,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.016285100891320216,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022958995277921269,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.04292565565938402,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.035832889447705407,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0076375720240257298,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0025292852950785337,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0074999189336587262,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.013298824435413661,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0083719165112395872,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.010937529534189205,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0055970499649441487,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015333777533125656,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.010883771708740528,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.031586997663798605,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.046160092830032279,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.027428872302552119,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0036901219809365336,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.020084790465151565,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.020857489570537006,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023329232185614952,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030276613904093492,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.031996131976561253,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0031828077769577127,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0023087024702132821,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0027898161931620476,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0015746606470324407,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0028155354301804183,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-2.369081706148724e-05,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013022992152182677,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0099475174313192142,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.020221114206112997,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.026165159286670452,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.027802279821062547,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.034341419523136449,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.005404998759012584,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.006491935846107127,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.00023700360534321691,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01592714714920752,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.008230908862874118,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.020949304560737399,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.010201902352789997,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0047308077226292334,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0091138598185522557,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0059986589576908785,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015777874485397334,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.024345510389183977,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0057721601529527287,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0021251094890165599,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.013125533308366017,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.027603069086893899,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030165265193643903,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.037384475940486502,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0092295147964698999,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.012410349635904989,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.02320439666207973,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.055799475519744256,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.067656025422966656,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.062898499628533208,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0075952417644682343,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.012296147488534822,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.026566768544906378,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.014620588787266178,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.013150767659284378,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.011997006052518914,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031644762949319949,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0074555693700670651,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.004862935147969775,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.016966484603561857,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018291919413607891,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.027124552205818716,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.039271348858736566,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0023703254668453696,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.012133487353179925,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.02654816092091002,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0040560395357429162,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (9.4324694861213006e-06,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024168636637814562,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.013192109874414035,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.026464671890183304,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.038646775725604696,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.036037654314935698,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018535837287617207,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.019269430117356604,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024722307940454259,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0023748357899529299,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022738075282812416,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015584102121292839,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0034704120850343337,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025107364214199374,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.011667328731661564,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0032307902919290216,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018098668320330698,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028176798243559398,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.063383729551304654,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025224094461004515,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.016759227642170721,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013540352346787727,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029893723637053442,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0027740726595744899,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.023323095298589811,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042329148471802254,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.017473505243423098,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028696013196645012,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.047001153654283152,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025635768119069775,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.050781837793748855,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025743555402545967,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014604292194616106,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022878692771432847,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0010369588856961847,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0046823326852659317,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0040510040427192695,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040746710073780723,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025782278082145321,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.023567308286657904,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025254913294012304,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.027614429692757292,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.032409862411932271,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025562186859512007,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028117640480887912,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.010839261865438888,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.010624435039198363,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.017341753626404863,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.033422743270032147,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024511631742478609,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.019883624797036231,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0097176013708311689,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.057995891775061668,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028918853886613166,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.030947028958529067,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022316697212154148,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031927356252865628,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (1.3730848720024807e-05,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
# ...
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.017622619914743416,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030865851690836252,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.023655346405752595,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.003297096323725371,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0014321002500417286,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015723199331338956,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.040515308965887141,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.032324726244780687,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.12620581658290816,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.030665480392060945,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0058838510466254577,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022936088387184132,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.024051738668008037,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.021902844789108915,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.010559262619247688,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01465795247103488,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023021371389104837,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.032445649241155804,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018276952036455713,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.012415633712061365,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0087960568702141265,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0091669382715549169,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018705376533668331,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.021439717815212683,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022375387784216706,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030509104669612087,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0086223572828564594,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015236427234049535,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.026178606998627299,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028658973817144773,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028452466570461816,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.053382799697156723,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0038434359957733406,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.009865523867742268,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01562449548620375,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.00090686776073480718,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018094632467350671,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.036256957496505073,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0076162810978840766,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.014009018035034572,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0075529619618960459,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015177212229722001,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0066253786773306927,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0033110481348702279,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0092574974992335364,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0038828749186383036,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0095475414883537842,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.016620487192731674,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.017887011906927954,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.036955035771540204,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.018679606269989428,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0078490851607427078,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025055538959519646,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.026191822036036788,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  ...]

# %%
resp= sorted(resp,key= lambda x: x[0])

# %%
resp[-10:-1]
# Out:
# [(0.21392383958194158,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.22012433710213719,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.4,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.22582912037014199,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.4,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.23607471421272327,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.4,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.23881138968768886,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.26244562635322849,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.45594433980831439,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.4,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.46399747893808663,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'bbc',
#    'grid_size': 7,
#    'learning_rate': 0.4,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.48257870790747892,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'bbc',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TF',
#    'tamanho': '3k'})]

# %% [markdown]
# # Resumo Reuters SOM

# %%
resp=[]
for f in os.listdir("../../Objetos/ObjetosProcessadosReutersAmostraSOM/REUTERS"):
    resp=resp+pickle.load(open("../../Objetos/ObjetosProcessadosReutersAmostraSOM/REUTERS/"+f,"rb"))

# %%
resp
# Out:
# [(0.069395888712349002,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.013962591854142467,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.047131986051080779,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.071173990205974855,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.091005196541484548,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.06296262572573709,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069154146141142653,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.041337806311058461,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.066268309186882077,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.040452460335819819,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.048447290222339547,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.02134106223496815,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0083524165808143598,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018947822707790135,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.048306486756078411,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025862627555820451,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.090388758008860259,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.11437091756362039,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015187199186460616,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.016542364260673115,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.032834749875166339,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.072592489640824515,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.070232653791157854,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.066159700716018094,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022428040092518853,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.020152016942975328,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.065706235239614316,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.058437692286860778,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.079813585854756716,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.067281621411811182,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.068411440436044982,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0086352800223882063,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.010276544508046654,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0092647138801167754,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.038132249163284629,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.092937316319908952,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021813555673557534,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.040058218500762154,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.039056377612115639,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.071365792820018314,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.064315117995322288,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.061355610192140517,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.012378659051050768,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0079766522660261827,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.045535127928145042,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.058144315460369425,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.059011639994601427,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.085277777824017839,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.070145532022524285,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0373549516015231,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.040076681667573832,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.045944171504628428,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.060867754184756262,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.057428975937961653,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026546558548622562,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0031001108021231536,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.040438876185728889,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.033287887487366136,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.064738792979246881,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.085140379956371262,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.058630032319820821,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018150799264488846,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.04792221759543526,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.067559855625396653,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.074467795146942281,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.085418842041211293,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.012090861594861991,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0095839153428796484,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.015409807069396222,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.083047308609321663,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.077854704787474707,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.090487830629344665,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.070399250383677545,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.046881543946077832,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.03448514954057081,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.060501219165998356,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.041580927828480704,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.072263937703597056,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.033029602458831596,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025541954197314684,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.040754956230796946,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.065007535843808625,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.080092566370064608,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.074301023356664525,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.017272871801618739,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.017558057864729724,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01445992808903785,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028285694882105233,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.039762741685494152,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.047011179055853336,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.075952161988772082,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.043365856649403151,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.036652944952236824,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.058435130980328022,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0755979224784466,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.072685880803907227,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.048003647795456614,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0373572359982682,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01254474022749473,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.017547755327560546,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.017823987461687327,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.00066689397926696689,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10181575851977334,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.029644715157926896,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.049788255483157642,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.038487643618029185,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.048543998800019188,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.042120455679074915,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031908956254564053,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (3.1407616990127471e-06,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028604360858441112,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.025371760601559334,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022834783464828343,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.055065717476360777,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027053492618282257,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.066517892643325291,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.066658913805951431,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.017765171231468823,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028916246778659494,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023798917806891289,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060208444180203977,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.003096748878200245,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028773292105895309,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.001442753095667218,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0030014018733528942,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030726603829917376,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040670901823130122,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023047471548250254,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0045855041090464496,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0071152642902080733,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023827519588390331,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028661372025692824,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.043740718781605917,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.035399752954211737,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.060047142170951993,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.062992567663929536,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0725757419150206,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.082722438650166444,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.062743515855545648,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0088437235637331552,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018717248408207703,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021655076674248451,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0083162425871321135,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.018004989645034906,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.045046757727314854,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0040873520580810554,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023961725231493997,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.027698588168607409,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022938351384444305,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.022694173741047128,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.046495250407036254,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0042110888198664169,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.041861006843760637,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.052605689193871916,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.051159869629146287,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.056266747390749397,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037287334928360734,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.046875281633865673,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.052105418536842391,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.039902031880958505,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01674857669258557,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.010697440837280007,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.05577676513936005,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.1,
#    'ncluster': 2,
# ...
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030682682918030581,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.044550844198329553,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.073691701363167175,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0019056540151143146,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.014834155395178052,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.00064090289674728629,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0011185436349958845,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.021758837427161115,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.091604597402486415,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01716581007382691,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0046108550837779538,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.037750672544416088,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0098763732615656016,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.030938081242132837,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035755320375758071,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.028840416589834616,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.046366663091170511,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.055286982906080341,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.063549953296481429,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.082057437143794126,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022071505163227451,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.01597103476714417,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.052425375376386057,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.076460409884394662,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.050270495336195674,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.087763730962595057,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 3,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.020637085077941819,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.023364574648220681,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.053536969071283108,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.073688080054669119,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.075206948782482061,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.085398026924052933,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027001930581096543,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.036604333449816555,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.033450323042988811,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.045179329868810722,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.044842271481011296,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.069657989865597278,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.03343716271799331,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.033247630651963754,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.029595530808458333,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.03092424288774499,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.093025290405780989,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.092434709904381157,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.054684733505626665,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.043843798104420441,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.037995233113081603,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.061962500327100087,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.058961328023827204,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 6,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.035930273935897337,
#   {'LSA': False,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.7,
#    'ncluster': 7,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.048092385129534981,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.046497109186538828,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.067119451137858555,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 4,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.074178179214543366,
#   {'LSA': False,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 5,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  ...]

# %%
resp= sorted(resp,key= lambda x: x[0])

# %%
resp[-10:-1]
# Out:
# [(0.24507177449078607,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.4,
#    'ncluster': 6,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.25189682401311653,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.25587962861229607,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 7,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.25996494880875426,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.26321445108184627,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.4,
#    'ncluster': 2,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.26492605992642548,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.26986928729866994,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 14,
#    'learning_rate': 0.1,
#    'ncluster': 3,
#    'neighboorhood_radius': 7,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'}),
#  (0.27539720986870475,
#   {'LSA': True,
#    'a_cooling': 'linear',
#    'corpus': 'reuters',
#    'grid_size': 7,
#    'learning_rate': 0.7,
#    'ncluster': 2,
#    'neighboorhood_radius': 2,
#    'processamento': 'Normal',
#    'r_cooling': 'linear',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.29708021195045248,
#   {'LSA': True,
#    'a_cooling': 'exponential',
#    'corpus': 'reuters',
#    'grid_size': 10,
#    'learning_rate': 0.4,
#    'ncluster': 3,
#    'neighboorhood_radius': 5,
#    'processamento': 'Lemma',
#    'r_cooling': 'linear',
#    'representacao': 'TFIDF',
#    'tamanho': '3k'})]

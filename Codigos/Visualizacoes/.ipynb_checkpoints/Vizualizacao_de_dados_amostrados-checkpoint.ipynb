# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle

# %%
os.listdir("../Codigos Processamento/SOM/BBC")
# Out:
# ['somBinario0.1.jojo',
#  'somBinario0.4.jojo',
#  'somBinario0.7.jojo',
#  'somTF0.1.jojo',
#  'somTF0.4.jojo',
#  'somTF0.7.jojo',
#  'somTFIDF0.1.jojo',
#  'somTFIDF0.4.jojo',
#  'somTFIDF0.7.jojo']

# %%
os.listdir("../../Objetos/Objetos Processados Amostra/Binario")
# Out:
# ['Binario2.jojo',
#  'Binario3.jojo',
#  'Binario4.jojo',
#  'Binario5.jojo',
#  'Binario6.jojo',
#  'Binario7.jojo']

# %%
os.listdir("../../Objetos/Objetos Processados Amostra/TF")
# Out:
# ['TF2.jojo',
#  'TF3.jojo',
#  'TF4.jojo',
#  'TF5.jojo',
#  'TF6.jojo',
#  'TF7.jojo',
#  'TF8.jojo']

# %%
answers=[]
for f in os.listdir("../../Objetos/Objetos Processados Amostra/Binario/"):
    answers=answers+pickle.load(open("../../Objetos/Objetos Processados Amostra/Binario/"+f,"rb"))

# %%
for f in os.listdir("../../Objetos/Objetos Processados Amostra/TF/"):
    if "8" not in f:
        answers=answers+pickle.load(open("../../Objetos/Objetos Processados Amostra/TF/"+f,"rb"))

# %%
answers
# Out:
# [(0.054734430430321689,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.06534385930667877,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.066397470463681302,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.096013628721082198,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013360237143752328,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014069377935719357,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.078075769963038846,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10168695015598316,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060225903458431117,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060289351881749713,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040458869551154637,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.038707287630471911,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026827346536377066,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.049699673149886082,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069375001517181956,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.043951676095973398,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014567034513222849,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015471077266014517,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.090463597896319248,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10244791673787269,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061057641008741649,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.12430025582676983,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042408579676745585,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042105583069716589,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025422929534414242,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028726224420243519,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.06187660785399695,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.064746195457121763,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.00023953460723818352,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0014662808805879213,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031686235793384393,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084286406647322801,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069667675097183496,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041003843807895325,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029557831451318416,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029263752052331157,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013288689080594513,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.044035945613629779,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.045665835633949277,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047558039801171376,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0019903249870650377,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0012887786658651835,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.063100689494330398,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.07775622981425484,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.059271185183921063,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042913046049159118,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.02836732520571824,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.032906431623914864,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031922227234589436,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042576412646885456,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04579217201883156,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.050115386401721217,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0049590971020801169,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.005261707470095885,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04859025386531525,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.086344097421111612,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0097139496851319576,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042417742227494802,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024397685509190595,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024797439064939236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.03315159126475354,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047507305613318264,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.043660983652956557,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.023546294793924481,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0022530204376111102,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0042524818387916618,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.046491104291915906,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.078916200310329268,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036557674321343478,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04970577398629835,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027036867773624223,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029958810399921171,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026186383049698291,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036773628494279363,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.032474871616077795,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041667465666012683,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0058526438346805697,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0077652852915041353,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042214731294690513,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069065994773407191,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013534627758909283,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061169443729664,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024684876198708919,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0236664732246002,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.018452310926290513,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.034889601868142502,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042957779286885177,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.039319671582061046,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0041284211338215339,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0047826239849849995,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.053567104925240347,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.079675900259432511,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021482735661403581,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041252943653178283,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027926374437861372,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024441292226441966,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061477253542843315,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026090606150627853,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029858731804740565,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035851988537583666,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0063585074254153108,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0071416355851917305,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.064881324952895073,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084110309142707784,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.054158288586082494,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.062297478847785505,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027156103583895665,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024975148196241258,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022639679573826919,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.033292938398709788,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021981634430093305,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.020540572738044726,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0039480537294416494,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0052173499381435043,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037002140504355893,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084774300993778307,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037196556176971089,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.075753743569774476,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028409325370080171,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027165762035327799,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035809339590075796,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042758257461178541,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.039375741038294117,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036587729083360949,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0030980470300202606,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0073574818629815412,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047117820171647194,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.067856110842798925,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015888835724019685,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060373048904773886,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026280686958293751,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027940474427684804,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040155456383959093,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035213107426522908,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036717320075739621,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0220922354168906,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0040962311438385735,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0053241056857707891,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040240405722010715,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.071421345946660414,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.038991087588940605,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041106276117043199,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.030245006546273726,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024056588759188979,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.085341148014760407,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.09081694415994046,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.13297936944870956,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.1078142294244977,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.025916604643024511,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.025389019145682059,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.12447035070729316,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17930798376732812,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.1407549597078471,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.15968890084604881,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.053449748578781597,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05379528440447575,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.085425123292250799,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.092427952757621279,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16553209534864324,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16713600927673644,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.036502501015967984,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.036879927696407251,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16391603784766551,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17348930388890527,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16167236082935968,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.14586059981856236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.068673271845454797,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.068037389131433645,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.074635016330161577,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.082415874873757719,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.095060855444857525,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10133751626912578,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0038528517002206033,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0066272853276782518,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072617687729765998,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11267023463285346,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056059320732186758,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16184101061327236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.012562947623392747,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.015510043835803965,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.039593745818880428,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.061220685970820712,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10221722403402128,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11009597794099875,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0092564990764773519,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0058919077751055822,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05613047493185478,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10458846648605982,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056487307570670352,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10425592827118965,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.034405046635696393,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.030818348238587989,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.033142580542859186,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.050243577867608517,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.058527362238588607,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066901092729153427,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019603266612154242,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.017253902993702514,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.073756781954574163,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
# ...
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019407304911725258,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.043755914056370158,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11110271756729384,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.005449153390620274,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.085185437340799988,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0020281276134014431,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0056198448272793584,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021843150904248244,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.022109143205111339,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.054009353888396026,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.071762070475037326,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.015245923557917269,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.012595859498369392,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.029605879310544321,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.089296789109317293,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.037786878851126991,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.050281695775557002,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010892196333679865,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010646148475101416,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.040661466611767387,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.052977648290630085,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066382315892593358,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.051663518352831318,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.017445687145775966,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.02096321005982928,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.051507752746994928,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.070646897878842735,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.012515263461163792,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066203591290945399,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0039078451271880622,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0083383318534596719,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021911490497655277,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0314131588268204,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.067777526086304954,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.077326886272088738,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0075046643200963404,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.011551417627911741,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.024780757379611586,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066151150236410175,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.035565842885513253,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.07281072162548137,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.011543190438991262,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010412971915402667,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.038019711893075604,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.041445557812540966,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.055509291483902094,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056105788931040679,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.022642402082901629,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.020328638105172325,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.052306242241269188,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.078251405305339403,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0091443452739734012,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.048204317688501634,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0097818957671428949,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0088158922419796851,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.031200673156803971,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.037889030027328539,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.049464738174000981,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072344010875381379,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.014502554974302761,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.016165573566372424,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.026124751328542993,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072863344631328084,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.019732606749965059,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.071036634101823357,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.009247962877967749,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.001536725185968709,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'})]

# %%
sorted(sorted(answers,key=lambda x:x[1]['LSA']),key=lambda x:x[1]['distancia'])
# Out:
# [(0.013360237143752328,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014069377935719357,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014567034513222849,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015471077266014517,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.00023953460723818352,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0014662808805879213,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0019903249870650377,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0012887786658651835,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0049590971020801169,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.005261707470095885,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0022530204376111102,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0042524818387916618,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0058526438346805697,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0077652852915041353,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0041284211338215339,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0047826239849849995,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0063585074254153108,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0071416355851917305,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0039480537294416494,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0052173499381435043,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0030980470300202606,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0073574818629815412,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0040962311438385735,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0053241056857707891,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025916604643024511,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.025389019145682059,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.036502501015967984,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.036879927696407251,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0038528517002206033,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0066272853276782518,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0092564990764773519,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0058919077751055822,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019603266612154242,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.017253902993702514,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0074201019471090901,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.011055181950618716,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.01750794474180558,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019407304911725258,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.015245923557917269,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.012595859498369392,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.017445687145775966,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.02096321005982928,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0075046643200963404,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.011551417627911741,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.022642402082901629,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.020328638105172325,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.014502554974302761,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.016165573566372424,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019504411941589431,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.023202928367179972,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.014314307805602989,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.015775159268824623,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.040458869551154637,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.038707287630471911,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042408579676745585,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042105583069716589,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029557831451318416,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029263752052331157,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.02836732520571824,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.032906431623914864,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024397685509190595,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024797439064939236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027036867773624223,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029958810399921171,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024684876198708919,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0236664732246002,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027926374437861372,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024441292226441966,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027156103583895665,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024975148196241258,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028409325370080171,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027165762035327799,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026280686958293751,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027940474427684804,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.030245006546273726,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024056588759188979,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.053449748578781597,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05379528440447575,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.068673271845454797,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.068037389131433645,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.012562947623392747,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.015510043835803965,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.034405046635696393,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.030818348238587989,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0042023824115973328,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.00072942459878754039,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.012833964162047521,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0067306340315059941,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0020281276134014431,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0056198448272793584,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010892196333679865,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010646148475101416,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0039078451271880622,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0083383318534596719,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.011543190438991262,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010412971915402667,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0097818957671428949,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0088158922419796851,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.009247962877967749,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.001536725185968709,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0039916662031675527,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0086709628825854812,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0087960593776200725,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0063930764587597413,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.054734430430321689,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.06534385930667877,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026827346536377066,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.049699673149886082,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025422929534414242,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028726224420243519,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013288689080594513,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.044035945613629779,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031922227234589436,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042576412646885456,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.03315159126475354,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047507305613318264,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026186383049698291,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036773628494279363,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.018452310926290513,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.034889601868142502,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061477253542843315,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026090606150627853,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022639679573826919,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.033292938398709788,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035809339590075796,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042758257461178541,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040155456383959093,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035213107426522908,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.085341148014760407,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.09081694415994046,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.085425123292250799,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.092427952757621279,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.074635016330161577,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.082415874873757719,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.039593745818880428,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.061220685970820712,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.033142580542859186,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.050243577867608517,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.03972422851935678,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.03938749570255571,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021097336455031805,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.044682240287281912,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021843150904248244,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.022109143205111339,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.040661466611767387,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.052977648290630085,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021911490497655277,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0314131588268204,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.038019711893075604,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.041445557812540966,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.031200673156803971,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.037889030027328539,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.024141344602625216,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.069678666518414784,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.013540457741029082,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.049138489003417711,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.078075769963038846,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10168695015598316,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.090463597896319248,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10244791673787269,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031686235793384393,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084286406647322801,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.063100689494330398,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.07775622981425484,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04859025386531525,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.086344097421111612,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.046491104291915906,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.078916200310329268,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042214731294690513,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069065994773407191,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.053567104925240347,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.079675900259432511,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.064881324952895073,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084110309142707784,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037002140504355893,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084774300993778307,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047117820171647194,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.067856110842798925,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040240405722010715,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.071421345946660414,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.12447035070729316,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17930798376732812,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16391603784766551,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17348930388890527,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072617687729765998,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11267023463285346,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05613047493185478,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10458846648605982,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.073756781954574163,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.087198871871104186,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.033806611667164255,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.08989992007295973,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.043755914056370158,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11110271756729384,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.029605879310544321,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.089296789109317293,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.051507752746994928,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.070646897878842735,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.024780757379611586,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066151150236410175,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
# ...
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.054009353888396026,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.071762070475037326,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066382315892593358,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.051663518352831318,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.067777526086304954,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.077326886272088738,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.055509291483902094,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056105788931040679,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.049464738174000981,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072344010875381379,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05207360617028383,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072414033002698247,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.058419911045767596,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.060534547175011041,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.060225903458431117,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060289351881749713,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061057641008741649,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.12430025582676983,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069667675097183496,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041003843807895325,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.059271185183921063,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042913046049159118,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0097139496851319576,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042417742227494802,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036557674321343478,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04970577398629835,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013534627758909283,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061169443729664,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021482735661403581,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041252943653178283,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.054158288586082494,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.062297478847785505,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037196556176971089,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.075753743569774476,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015888835724019685,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060373048904773886,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.038991087588940605,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041106276117043199,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.1407549597078471,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.15968890084604881,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16167236082935968,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.14586059981856236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056059320732186758,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16184101061327236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056487307570670352,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10425592827118965,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.027836544442553228,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.058116894637528928,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.025930026973099214,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10781240817458933,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.005449153390620274,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.085185437340799988,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.037786878851126991,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.050281695775557002,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.012515263461163792,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066203591290945399,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.035565842885513253,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.07281072162548137,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0091443452739734012,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.048204317688501634,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.019732606749965059,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.071036634101823357,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.02397848129035467,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072290861102715903,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.029522248629050337,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.073936419902196043,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'})]

# %%
def funnnc(x):
    return x[0][x[1]]

# %%
def check_parity(d1,d2,var):
    conf=set()
    for v in d1[1].keys():
        if not v==var:
            if not d1[1][v]==d2[1][v]:
                return False
    return True

# %%
def ordenador(data):

# %%
sorted(answers,key=lambda x:x[1]['processamento'])
# Out:
# [(0.026827346536377066,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.049699673149886082,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069375001517181956,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.043951676095973398,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014567034513222849,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.015471077266014517,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.090463597896319248,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10244791673787269,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.061057641008741649,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.12430025582676983,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042408579676745585,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042105583069716589,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013288689080594513,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.044035945613629779,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.045665835633949277,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047558039801171376,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0019903249870650377,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0012887786658651835,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.063100689494330398,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.07775622981425484,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.059271185183921063,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042913046049159118,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.02836732520571824,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.032906431623914864,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.03315159126475354,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.047507305613318264,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.043660983652956557,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.023546294793924481,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0022530204376111102,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0042524818387916618,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.046491104291915906,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.078916200310329268,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036557674321343478,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04970577398629835,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027036867773624223,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029958810399921171,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.018452310926290513,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.034889601868142502,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042957779286885177,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.039319671582061046,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0041284211338215339,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0047826239849849995,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.053567104925240347,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.079675900259432511,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021482735661403581,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041252943653178283,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027926374437861372,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024441292226441966,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.022639679573826919,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.033292938398709788,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.021981634430093305,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.020540572738044726,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0039480537294416494,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0052173499381435043,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037002140504355893,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084774300993778307,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.037196556176971089,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.075753743569774476,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028409325370080171,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.027165762035327799,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040155456383959093,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.035213107426522908,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036717320075739621,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0220922354168906,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0040962311438385735,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0053241056857707891,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040240405722010715,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.071421345946660414,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.038991087588940605,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041106276117043199,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.030245006546273726,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024056588759188979,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.085425123292250799,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.092427952757621279,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16553209534864324,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16713600927673644,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.036502501015967984,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.036879927696407251,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16391603784766551,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.17348930388890527,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16167236082935968,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.14586059981856236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.068673271845454797,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.068037389131433645,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.039593745818880428,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.061220685970820712,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10221722403402128,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11009597794099875,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0092564990764773519,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0058919077751055822,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05613047493185478,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10458846648605982,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056487307570670352,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10425592827118965,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.034405046635696393,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.030818348238587989,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.03972422851935678,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.03938749570255571,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.082054918922295703,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10597974394143987,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0074201019471090901,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.011055181950618716,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.033806611667164255,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.08989992007295973,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.025930026973099214,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.10781240817458933,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.012833964162047521,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0067306340315059941,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021843150904248244,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.022109143205111339,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.054009353888396026,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.071762070475037326,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.015245923557917269,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.012595859498369392,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.029605879310544321,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.089296789109317293,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.037786878851126991,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.050281695775557002,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010892196333679865,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010646148475101416,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021911490497655277,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0314131588268204,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.067777526086304954,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.077326886272088738,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.0075046643200963404,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.011551417627911741,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.024780757379611586,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066151150236410175,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.035565842885513253,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.07281072162548137,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.011543190438991262,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.010412971915402667,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.031200673156803971,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.037889030027328539,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.049464738174000981,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072344010875381379,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.014502554974302761,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.016165573566372424,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.026124751328542993,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072863344631328084,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.019732606749965059,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.071036634101823357,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.009247962877967749,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.001536725185968709,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.013540457741029082,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.049138489003417711,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.058419911045767596,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.060534547175011041,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.014314307805602989,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.015775159268824623,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.029848692001261792,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072951936366288675,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.029522248629050337,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.073936419902196043,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0087960593776200725,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0063930764587597413,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Lemma',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.054734430430321689,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.06534385930667877,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.066397470463681302,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.096013628721082198,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.013360237143752328,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.014069377935719357,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.078075769963038846,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.10168695015598316,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060225903458431117,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.060289351881749713,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.040458869551154637,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.038707287630471911,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 2,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.025422929534414242,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.028726224420243519,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.06187660785399695,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.064746195457121763,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.00023953460723818352,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0014662808805879213,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031686235793384393,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.084286406647322801,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069667675097183496,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041003843807895325,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029557831451318416,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.029263752052331157,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.031922227234589436,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042576412646885456,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04579217201883156,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.050115386401721217,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0049590971020801169,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.005261707470095885,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.04859025386531525,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.086344097421111612,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.0097139496851319576,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042417742227494802,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024397685509190595,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.024797439064939236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.026186383049698291,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.036773628494279363,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.032474871616077795,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.041667465666012683,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0058526438346805697,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (-0.0077652852915041353,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.042214731294690513,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'Binario',
#    'tamanho': '3k'}),
#  (0.069065994773407191,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
# ...
#    'tamanho': '3k'}),
#  (-0.0066272853276782518,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072617687729765998,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11267023463285346,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056059320732186758,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.16184101061327236,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.012562947623392747,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.015510043835803965,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 3,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.033142580542859186,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.050243577867608517,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.058527362238588607,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066901092729153427,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019603266612154242,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.017253902993702514,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.073756781954574163,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.087198871871104186,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.027836544442553228,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.058116894637528928,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0042023824115973328,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.00072942459878754039,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 4,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.021097336455031805,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.044682240287281912,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.073197643196533449,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066306465176851528,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.01750794474180558,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019407304911725258,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.043755914056370158,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.11110271756729384,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.005449153390620274,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.085185437340799988,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0020281276134014431,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0056198448272793584,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 5,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.040661466611767387,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.052977648290630085,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066382315892593358,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.051663518352831318,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.017445687145775966,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.02096321005982928,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.051507752746994928,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.070646897878842735,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.012515263461163792,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.066203591290945399,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0039078451271880622,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0083383318534596719,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 6,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.038019711893075604,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.041445557812540966,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.055509291483902094,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.056105788931040679,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.022642402082901629,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.020328638105172325,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.052306242241269188,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.078251405305339403,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0091443452739734012,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.048204317688501634,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0097818957671428949,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0088158922419796851,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 7,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.024141344602625216,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.069678666518414784,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.05207360617028383,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072414033002698247,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.019504411941589431,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (-0.023202928367179972,
#   {'LSA': False,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.031293004090884514,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.074439629420676695,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'euclidiana',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.02397848129035467,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.072290861102715903,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'manhattan',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0039916662031675527,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': 'padrao',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'}),
#  (0.0086709628825854812,
#   {'LSA': True,
#    'algoritmo': 'media',
#    'corpus': 'bbc',
#    'distancia': 'cosseno',
#    'inicializacao': '++',
#    'ncluster': 8,
#    'processamento': 'Normal',
#    'representacao': 'TF',
#    'tamanho': '3k'})]

# %%
a=set()
a.add(1)
print(a)
len(a)
# Out:
# {1}
# 1

# %%
def verifica_consistencia(lista, variavel):
    conf=set()
    print(lista)
    for f in lista[0][1].keys():
        if not f==variavel:
            conf.add(lista[0][1][f])
    print(conf)
    i=0
    for l in lista:
        print(i)
        print(l)
        i=i+1
        for f in l[1].keys():
            if not f==variavel:
                print(l[1][f])
                if l[1][f] not in conf:
                    return True
    return False

# %%
def Plot_Samples(samples, variable,representation = True):
    if variable not in samples[0][1].keys():
        raise ValueError("not a valid key")
    sorted_sample=samples
    dif_keys=[]
    
    for s in samples:
        if s[1][variable] not in dif_keys:
            dif_keys.append(s[1][variable])
    
    for v in samples[0][1].keys():
        if not v == variable:
            print(v)
            sorted_sample=sorted(sorted_sample,key=lambda x: x[1][v])
    x=[]
    y=[]
    labell=""
    conf=set()
    figz=[]
    acc=[]
    count=0
    for i,s in enumerate(sorted_sample):
        count=count+1
        print(count,len(dif_keys))
        if((count%len(dif_keys))==0):
            print("entrou")
            x.append(s[1][variable])
            y.append(s[0])
            print(x)
            print(y)
            if(verifica_consistencia(acc,variable)):
                raise ValueError("kasdk")
            
            plot= sorted([(x[i],y[i]) for i in range(len(x))])
            x=[]
            y=[]
            acc=[]

            fig, ax = plt.subplots()
            title=""
            for t in conf:
                title=title+ " "+t
            conf=set()
            for v in samples[i][1].keys():
                if not v==variable:
                    conf.add(v+": "+str(samples[i][1][v]))
            fig.suptitle(title)
            ax.set_ylabel("Silhueta")
            ax.set_xlabel(variable)
            ax.plot([xx[0] for xx in plot],[yy[1] for yy in plot],label=labell)
            ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
            figz.append(fig)
        else:
            
            x.append(s[1][variable])
            y.append(s[0])
            acc.append(s)

            
    return figz

# %%
0==0.0
# Out:
# True

# %%
figos=Plot_Samples(answers,'ncluster')
# Out:
# corpus
# representacao
# tamanho
# processamento
# LSA
# algoritmo
# distancia
# inicializacao
# 1 6
# 2 6
# 3 6
# 4 6
# 5 6
# 6 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.015471077266014517, 0.0012887786658651835, -0.0042524818387916618, -0.0047826239849849995, -0.0052173499381435043, -0.0053241056857707891]
# [(0.015471077266014517, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0012887786658651835, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.0042524818387916618, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.0047826239849849995, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.0052173499381435043, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {False, 'Lemma', '++', '3k', 'media', 'bbc', 'cosseno', 'Binario'}
# 0
# (0.015471077266014517, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 1
# (0.0012887786658651835, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 2
# (-0.0042524818387916618, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 3
# (-0.0047826239849849995, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# media
# cosseno
# ++
# 4
# (-0.0052173499381435043, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 7 6
# 8 6
# 9 6
# 10 6
# 11 6
# 12 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.036879927696407251, 0.0058919077751055822, -0.011055181950618716, -0.012595859498369392, -0.011551417627911741, -0.016165573566372424]
# [(0.036879927696407251, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0058919077751055822, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.011055181950618716, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.012595859498369392, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.011551417627911741, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {False, 'Lemma', 'TF', '3k', 'media', 'bbc', 'cosseno', '++'}
# 0
# (0.036879927696407251, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 1
# (0.0058919077751055822, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 2
# (-0.011055181950618716, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 3
# (-0.012595859498369392, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 4
# (-0.011551417627911741, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# cosseno
# ++
# 13 6
# 14 6
# 15 6
# 16 6
# 17 6
# 18 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.014069377935719357, 0.0014662808805879213, -0.005261707470095885, -0.0077652852915041353, -0.0071416355851917305, -0.0073574818629815412]
# [(0.014069377935719357, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0014662808805879213, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.005261707470095885, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.0077652852915041353, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.0071416355851917305, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {False, '++', '3k', 'media', 'Normal', 'bbc', 'cosseno', 'Binario'}
# 0
# (0.014069377935719357, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# cosseno
# ++
# 1
# (0.0014662808805879213, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# cosseno
# ++
# 2
# (-0.005261707470095885, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# cosseno
# ++
# 3
# (-0.0077652852915041353, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# cosseno
# ++
# 4
# (-0.0071416355851917305, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# cosseno
# ++
# 19 6
# 20 6
# 21 6
# 22 6
# 23 6
# 24 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.025389019145682059, -0.0066272853276782518, -0.017253902993702514, -0.019407304911725258, -0.02096321005982928, -0.020328638105172325]
# [(0.025389019145682059, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.0066272853276782518, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.017253902993702514, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.019407304911725258, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (-0.02096321005982928, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {False, 'TF', '3k', 'media', 'Normal', 'bbc', 'cosseno', '++'}
# 0
# (0.025389019145682059, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# cosseno
# ++
# 1
# (-0.0066272853276782518, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# cosseno
# ++
# 2
# (-0.017253902993702514, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# cosseno
# ++
# 3
# (-0.019407304911725258, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# cosseno
# ++
# 4
# (-0.02096321005982928, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# cosseno
# ++
# 25 6
# 26 6
# 27 6
# 28 6
# 29 6
# 30 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.042105583069716589, 0.032906431623914864, 0.029958810399921171, 0.024441292226441966, 0.027165762035327799, 0.024056588759188979]
# [(0.042105583069716589, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.032906431623914864, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.029958810399921171, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.024441292226441966, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.027165762035327799, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {True, 'Lemma', '++', '3k', 'media', 'bbc', 'cosseno', 'Binario'}
# 0
# (0.042105583069716589, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 1
# (0.032906431623914864, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 2
# (0.029958810399921171, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 3
# (0.024441292226441966, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 4
# (0.027165762035327799, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 31 6
# 32 6
# 33 6
# 34 6
# 35 6
# 36 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.068037389131433645, 0.030818348238587989, 0.0067306340315059941, 0.010646148475101416, 0.010412971915402667, 0.001536725185968709]
# [(0.068037389131433645, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.030818348238587989, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0067306340315059941, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.010646148475101416, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.010412971915402667, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {True, 'Lemma', 'TF', '3k', 'media', 'bbc', 'cosseno', '++'}
# 0
# (0.068037389131433645, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 1
# (0.030818348238587989, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 2
# (0.0067306340315059941, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 3
# (0.010646148475101416, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 4
# (0.010412971915402667, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# cosseno
# ++
# 37 6
# 38 6
# 39 6
# 40 6
# 41 6
# 42 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.038707287630471911, 0.029263752052331157, 0.024797439064939236, 0.0236664732246002, 0.024975148196241258, 0.027940474427684804]
# [(0.038707287630471911, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.029263752052331157, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.024797439064939236, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0236664732246002, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.024975148196241258, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {True, '++', '3k', 'media', 'Normal', 'bbc', 'cosseno', 'Binario'}
# 0
# (0.038707287630471911, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# cosseno
# ++
# 1
# (0.029263752052331157, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# cosseno
# ++
# 2
# (0.024797439064939236, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# cosseno
# ++
# 3
# (0.0236664732246002, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# cosseno
# ++
# 4
# (0.024975148196241258, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# cosseno
# ++
# 43 6
# 44 6
# 45 6
# 46 6
# 47 6
# 48 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.05379528440447575, 0.015510043835803965, 0.00072942459878754039, 0.0056198448272793584, 0.0083383318534596719, 0.0088158922419796851]
# [(0.05379528440447575, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.015510043835803965, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.00072942459878754039, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0056198448272793584, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'}), (0.0083383318534596719, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})]
# {True, 'TF', '3k', 'media', 'Normal', 'bbc', 'cosseno', '++'}
# 0
# (0.05379528440447575, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# cosseno
# ++
# 1
# (0.015510043835803965, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# cosseno
# ++
# 2
# (0.00072942459878754039, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# cosseno
# ++
# 3
# (0.0056198448272793584, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# cosseno
# ++
# 4
# (0.0083383318534596719, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'cosseno', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# cosseno
# ++
# 49 6
# 50 6
# 51 6
# 52 6
# 53 6
# 54 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.049699673149886082, 0.044035945613629779, 0.047507305613318264, 0.034889601868142502, 0.033292938398709788, 0.035213107426522908]
# [(0.049699673149886082, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.044035945613629779, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.047507305613318264, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.034889601868142502, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.033292938398709788, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {False, 'Lemma', '++', '3k', 'media', 'bbc', 'euclidiana', 'Binario'}
# 0
# (0.049699673149886082, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 1
# (0.044035945613629779, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 2
# (0.047507305613318264, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 3
# (0.034889601868142502, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 4
# (0.033292938398709788, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 55 6
# 56 6
# 57 6
# 58 6
# 59 6
# 60 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.092427952757621279, 0.061220685970820712, 0.03938749570255571, 0.022109143205111339, 0.0314131588268204, 0.037889030027328539]
# [(0.092427952757621279, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.061220685970820712, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.03938749570255571, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.022109143205111339, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.0314131588268204, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {False, 'Lemma', 'TF', '3k', 'media', 'bbc', 'euclidiana', '++'}
# 0
# (0.092427952757621279, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 1
# (0.061220685970820712, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 2
# (0.03938749570255571, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 3
# (0.022109143205111339, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 4
# (0.0314131588268204, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# euclidiana
# ++
# 61 6
# 62 6
# 63 6
# 64 6
# 65 6
# 66 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.06534385930667877, 0.028726224420243519, 0.042576412646885456, 0.036773628494279363, 0.026090606150627853, 0.042758257461178541]
# [(0.06534385930667877, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.028726224420243519, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.042576412646885456, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.036773628494279363, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.026090606150627853, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {False, '++', '3k', 'media', 'Normal', 'bbc', 'euclidiana', 'Binario'}
# 0
# (0.06534385930667877, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 1
# (0.028726224420243519, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 2
# (0.042576412646885456, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 3
# (0.036773628494279363, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 4
# (0.026090606150627853, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 67 6
# 68 6
# 69 6
# 70 6
# 71 6
# 72 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.09081694415994046, 0.082415874873757719, 0.050243577867608517, 0.044682240287281912, 0.052977648290630085, 0.041445557812540966]
# [(0.09081694415994046, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.082415874873757719, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.050243577867608517, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.044682240287281912, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.052977648290630085, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {False, 'TF', '3k', 'media', 'Normal', 'bbc', 'euclidiana', '++'}
# 0
# (0.09081694415994046, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 1
# (0.082415874873757719, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 2
# (0.050243577867608517, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 3
# (0.044682240287281912, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 4
# (0.052977648290630085, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# False
# media
# euclidiana
# ++
# 73 6
# 74 6
# 75 6
# 76 6
# 77 6
# 78 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.10244791673787269, 0.07775622981425484, 0.078916200310329268, 0.079675900259432511, 0.084774300993778307, 0.071421345946660414]
# [(0.10244791673787269, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.07775622981425484, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.078916200310329268, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.079675900259432511, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.084774300993778307, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {True, 'Lemma', '++', '3k', 'media', 'bbc', 'euclidiana', 'Binario'}
# 0
# (0.10244791673787269, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 1
# (0.07775622981425484, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 2
# (0.078916200310329268, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 3
# (0.079675900259432511, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 4
# (0.084774300993778307, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 79 6
# 80 6
# 81 6
# 82 6
# 83 6
# 84 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.17348930388890527, 0.10458846648605982, 0.08989992007295973, 0.089296789109317293, 0.066151150236410175, 0.072863344631328084]
# [(0.17348930388890527, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.10458846648605982, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.08989992007295973, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.089296789109317293, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.066151150236410175, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {True, 'Lemma', 'TF', '3k', 'media', 'bbc', 'euclidiana', '++'}
# 0
# (0.17348930388890527, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 1
# (0.10458846648605982, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 2
# (0.08989992007295973, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 3
# (0.089296789109317293, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 4
# (0.066151150236410175, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# euclidiana
# ++
# 85 6
# 86 6
# 87 6
# 88 6
# 89 6
# 90 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.10168695015598316, 0.084286406647322801, 0.086344097421111612, 0.069065994773407191, 0.084110309142707784, 0.067856110842798925]
# [(0.10168695015598316, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.084286406647322801, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.086344097421111612, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.069065994773407191, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.084110309142707784, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {True, '++', '3k', 'media', 'Normal', 'bbc', 'euclidiana', 'Binario'}
# 0
# (0.10168695015598316, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 1
# (0.084286406647322801, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 2
# (0.086344097421111612, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 3
# (0.069065994773407191, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 4
# (0.084110309142707784, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 91 6
# 92 6
# 93 6
# 94 6
# 95 6
# 96 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.17930798376732812, 0.11267023463285346, 0.087198871871104186, 0.11110271756729384, 0.070646897878842735, 0.078251405305339403]
# [(0.17930798376732812, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.11267023463285346, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.087198871871104186, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.11110271756729384, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'}), (0.070646897878842735, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})]
# {True, 'TF', '3k', 'media', 'Normal', 'bbc', 'euclidiana', '++'}
# 0
# (0.17930798376732812, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 1
# (0.11267023463285346, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 2
# (0.087198871871104186, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 3
# (0.11110271756729384, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 4
# (0.070646897878842735, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'euclidiana', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Normal
# True
# media
# euclidiana
# ++
# 97 6
# 98 6
# 99 6
# 100 6
# 101 6
# 102 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.043951676095973398, 0.047558039801171376, 0.023546294793924481, 0.039319671582061046, 0.020540572738044726, 0.0220922354168906]
# [(0.043951676095973398, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.047558039801171376, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.023546294793924481, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.039319671582061046, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.020540572738044726, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})]
# {False, 'Lemma', '++', '3k', 'media', 'bbc', 'Binario', 'manhattan'}
# 0
# (0.043951676095973398, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 1
# (0.047558039801171376, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 2
# (0.023546294793924481, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 3
# (0.039319671582061046, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 4
# (0.020540572738044726, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# Binario
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 103 6
# 104 6
# 105 6
# 106 6
# 107 6
# 108 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.16713600927673644, 0.11009597794099875, 0.10597974394143987, 0.071762070475037326, 0.077326886272088738, 0.072344010875381379]
# [(0.16713600927673644, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.11009597794099875, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.10597974394143987, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.071762070475037326, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'}), (0.077326886272088738, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})]
# {False, 'Lemma', 'TF', '3k', 'media', 'bbc', '++', 'manhattan'}
# 0
# (0.16713600927673644, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 1
# (0.11009597794099875, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 2
# (0.10597974394143987, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 3
# (0.071762070475037326, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 4
# (0.077326886272088738, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': '++'})
# bbc
# TF
# 3k
# Lemma
# False
# media
# manhattan
# ++
# 109 6
# 110 6
# 111 6
# 112 6
# 113 6
# 114 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.096013628721082198, 0.064746195457121763, 0.050115386401721217, 0.041667465666012683, 0.035851988537583666, 0.036587729083360949]
# ...
# media
# manhattan
# padrao
# 253 6
# 254 6
# 255 6
# 256 6
# 257 6
# 258 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.066397470463681302, 0.06187660785399695, 0.04579217201883156, 0.032474871616077795, 0.029858731804740565, 0.039375741038294117]
# [(0.066397470463681302, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.06187660785399695, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.04579217201883156, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.032474871616077795, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.029858731804740565, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})]
# {False, '3k', 'media', 'Normal', 'bbc', 'padrao', 'Binario', 'manhattan'}
# 0
# (0.066397470463681302, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 1
# (0.06187660785399695, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 2
# (0.04579217201883156, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 3
# (0.032474871616077795, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 4
# (0.029858731804740565, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 259 6
# 260 6
# 261 6
# 262 6
# 263 6
# 264 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.13297936944870956, 0.095060855444857525, 0.058527362238588607, 0.073197643196533449, 0.066382315892593358, 0.055509291483902094]
# [(0.13297936944870956, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.095060855444857525, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.058527362238588607, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.073197643196533449, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.066382315892593358, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})]
# {False, 'TF', '3k', 'media', 'Normal', 'bbc', 'padrao', 'manhattan'}
# 0
# (0.13297936944870956, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 1
# (0.095060855444857525, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 2
# (0.058527362238588607, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 3
# (0.073197643196533449, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 4
# (0.066382315892593358, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': False, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# False
# media
# manhattan
# padrao
# 265 6
# 266 6
# 267 6
# 268 6
# 269 6
# 270 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.061057641008741649, 0.059271185183921063, 0.036557674321343478, 0.021482735661403581, 0.037196556176971089, 0.038991087588940605]
# [(0.061057641008741649, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.059271185183921063, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.036557674321343478, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.021482735661403581, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.037196556176971089, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})]
# {True, 'Lemma', '3k', 'media', 'bbc', 'padrao', 'Binario', 'manhattan'}
# 0
# (0.061057641008741649, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 1
# (0.059271185183921063, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 2
# (0.036557674321343478, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 3
# (0.021482735661403581, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 4
# (0.037196556176971089, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 271 6
# 272 6
# 273 6
# 274 6
# 275 6
# 276 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.16167236082935968, 0.056487307570670352, 0.025930026973099214, 0.037786878851126991, 0.035565842885513253, 0.019732606749965059]
# [(0.16167236082935968, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.056487307570670352, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.025930026973099214, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.037786878851126991, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.035565842885513253, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})]
# {True, 'Lemma', 'TF', '3k', 'media', 'bbc', 'padrao', 'manhattan'}
# 0
# (0.16167236082935968, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 1
# (0.056487307570670352, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 2
# (0.025930026973099214, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 3
# (0.037786878851126991, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 4
# (0.035565842885513253, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Lemma', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Lemma
# True
# media
# manhattan
# padrao
# 277 6
# 278 6
# 279 6
# 280 6
# 281 6
# 282 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.060225903458431117, 0.069667675097183496, 0.0097139496851319576, 0.013534627758909283, 0.054158288586082494, 0.015888835724019685]
# [(0.060225903458431117, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.069667675097183496, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.0097139496851319576, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.013534627758909283, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.054158288586082494, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})]
# {True, '3k', 'media', 'Normal', 'bbc', 'padrao', 'Binario', 'manhattan'}
# 0
# (0.060225903458431117, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 1
# (0.069667675097183496, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 2
# (0.0097139496851319576, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 3
# (0.013534627758909283, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 4
# (0.054158288586082494, {'corpus': 'bbc', 'representacao': 'Binario', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# Binario
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 283 6
# 284 6
# 285 6
# 286 6
# 287 6
# 288 6
# entrou
# [2, 3, 4, 5, 6, 7]
# [0.1407549597078471, 0.056059320732186758, 0.027836544442553228, 0.005449153390620274, -0.012515263461163792, 0.0091443452739734012]
# [(0.1407549597078471, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.056059320732186758, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.027836544442553228, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (0.005449153390620274, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'}), (-0.012515263461163792, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})]
# {True, 'TF', '3k', 'media', 'Normal', 'bbc', 'padrao', 'manhattan'}
# 0
# (0.1407549597078471, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 2, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 1
# (0.056059320732186758, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 3, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 2
# (0.027836544442553228, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 4, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 3
# (0.005449153390620274, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 5, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# True
# media
# manhattan
# padrao
# 4
# (-0.012515263461163792, {'corpus': 'bbc', 'representacao': 'TF', 'tamanho': '3k', 'processamento': 'Normal', 'LSA': True, 'ncluster': 6, 'algoritmo': 'media', 'distancia': 'manhattan', 'inicializacao': 'padrao'})
# bbc
# TF
# 3k
# Normal
# True
# media
# manhattan
# padrao

# %%
len(answers)/6
# Out:
# 48.0

# %%
len(figos)
# Out:
# 48

# %%
figos[6]

# %%
[x for x in "ajsdkja kajdsn kjads hkjas hdkjas hd".strip().split() if x not in ["hd"]]
# Out:
# ['ajsdkja', 'kajdsn', 'kjads', 'hkjas', 'hdkjas']
